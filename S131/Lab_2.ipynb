# %% [markdown]
# **მონაცემთა ანალიზი პითონის გამოყენებით**
# <br>
# თარიღი: **2020 წლის 30 მაისი**
# <br>
#
# სათაური: **ლაბორატორიული №2: SciPy-ის ბიბლიოთეკა**
# <br>
# ჩაბარების ბოლო დღე: **2020 წლის 13 ივნისი**
# <br>
# თითო ამოცანა ფასდება **5 ქულით**.

# %% [markdown]
# <h3 align="center">ამოცანა 1: ვანდერმონდის მატრიცა</h3>
#
# - ვანდერმონდის მატრიცა ეს არის $m \times n$ მატრიცა სადაც ყოველი სტრიქონი არის გეომეტრიული პროგრესია:
#
# $$
# V =
# \begin{bmatrix}
# 1      & \alpha_1 & \alpha_1^2 & \cdots & \alpha_1^n\\
# 1      & \alpha_2 & \alpha_2^2 & \cdots & \alpha_2^n\\
# 1      & \alpha_3 & \alpha_2^2 & \cdots & \alpha_3^n\\
# \vdots & \vdots   & \vdots     & \ddots & \alpha_4^n\\
# 1      & \alpha_m & \alpha_m^2 & \cdots & \alpha_5^n
# \end{bmatrix}.$$
#
# (ა) გამოიყვანეთ კვადრატული  ვანდერმონდის მატრიცის (სადაც $m = n$) დეტერმინანტის ფორმულა:
#
# $$det(V) = \prod_{1 \leq i < j \leq n} (\alpha_i - \alpha_j).$$
#
# (ბ) დაწერეთ **python**-ის კოდი და აჩვენეთ, რომ მოუხედავად იმისა, რომ დეტერმინანტის ანალიტიკური ფორმულა ცხადი სახით არსებობს, მისი პრაქტიკული დათვლა გამოთვლითი მანქანების საშუალებით შეუძლებელია.
#
#   **მინიშნება**: დააგენერირეთ ვანდერმონდის მატრიცა სადაც თითოეული $\alpha$ არის ალბათობა ($0 \leq \alpha \leq 1$) და ცადეთ დათვალოთ კვადრატული  მატრიცის (სადაც $m = n$) დეტერმინანტი განსვავებული $n$-თვის, მაგალითად $n = 1, 2, ..., 100$.

# %% [markdown]
# <h3 align="center">ამოცანა 2: ალბათური განაწილების სიმკვრივე</h3>
#
# - განვიხილეთ შემდეგი ალბათობის განაწილებები (PDF):
#
#   1. **Poisson**: პუასონის განაწილება (**გასპარიანი კარენ**)
#   2. **Studnet**: სტუდენტის განაწილება (**გზირიშვილი ალექსანდრე**)
#   3. **Gamma**: გამმა ფუნქციის განაწილება (**ქიტოშვილი თემური**)
#   4. **Chi-squared**:ხიკვადრატის განაწილება (**ჭელიძე ჯემალ**)
#
#   შეგიძლიათ მოიხმარიოთ შემდეგი რესურსი:
#
#   https://www.boost.org/doc/libs/1_58_0/libs/math/doc/html/math_toolkit/dist_ref/dists/
#
#
# - შეასრულეთ შემდეგი დავალებები:
#   - განსაზღვრეთ განაწილების ფუნქციის (ყოველ სტუდენტს აქვს თავისი პირადი ფუნქცია);
#   - აირჩიეთ განსაზღვრის არე;
#   - დააგენერირეთ 1000 მონაცემი;
#   - დაუმატეთ ხმაური რომელიც არის ნორმალურად განაწილებული (გაუსის განაწილება $\mu = 1, \sigma = 0$);
#   - აირჩიეთ ბინინგი და ააგეთ ჰისტოგრამა;
#   - დაანორმირეტ ჰისტოგრამა ისე რომ ინტეგრალი უდრიდეს 1-ს;
#   - მოახდინეთ ჰისტოგრამის ფიტირება შესაბამისი განაწილების ფუნქციით და;
#   - ააგეთ საბოლოო გრაფიკი სადაც ნაჩვენები იქნება:
#     - თავდაპირველი განაწილების უწყვეტი ფუნქცია;
#     - დაკვირვების (ხმაურის დამატების შემდეგ) შედეგად მიღებულ ჰისტოგრამას;
#     - ფიტირების შედეგად მიღებული უწყვეტი ფუნქცია;
#     - $X$ და $Y$ ღეძების წარწერები (იარლიყები) გაზომვის ერთეულების ჩათვლით;
#     - ჰისტოგრამის დასახელება.
